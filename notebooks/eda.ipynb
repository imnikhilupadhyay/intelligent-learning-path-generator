# %% [markdown]
# # Exploratory data analysis
#
# Load processed CSVs from `data/processed/` after running `python run_ingestion.py`.
#
# Suggested checks: column distributions, missing `summary` fields, completion status values, and practice distribution in `user_master`.

# %%
import pandas as pd
from pathlib import Path

root = Path("..").resolve()
processed = root / "data" / "processed"
processed.exists()
