# %%
import pandas as pd
import random

# %%
file = "../data/raw/User Master List.xlsx"
df = pd.read_excel(file, sheet_name="Data")
df.head()
# Out:
#    Portal ID            firstname           lastname                    email  \
# 0      24453              Maureen           Khadloya  24453_sa@nttdataser.com
# 1      24430  Deepika Raghavendra                  R  24430_sa@nttdataser.com
# 2      24463              Shefali              Joisa  24463_sa@nttdataser.com
# 3      24465               Aastha             Kemkar  24465_sa@nttdataser.com
# 4      24277     Venkatasai Subra  Balkrishna Shedde  24277_sa@nttdataser.com
#
#   country  manager_portalid  grade employee_type  Training Goal  hireddate  \
# 0     IND           24687.0     12      Employee           16.0 1997-11-24
# 1     IND           24731.0     13      Employee           16.0 1998-03-02
# 2     IND           24716.0     13      Employee           16.0 1998-05-04
# 3     IND           24747.0     13      Employee           16.0 1998-05-18
# 4     IND           24749.0     13      Employee           16.0 1998-07-06
#
# ...

# %%
df['Training Goal'] = df['Training Goal'] + random.randint(2, 5)
df.head()
# Out:
#    Portal ID            firstname           lastname                    email  \
# 0      24453              Maureen           Khadloya  24453_sa@nttdataser.com
# 1      24430  Deepika Raghavendra                  R  24430_sa@nttdataser.com
# 2      24463              Shefali              Joisa  24463_sa@nttdataser.com
# 3      24465               Aastha             Kemkar  24465_sa@nttdataser.com
# 4      24277     Venkatasai Subra  Balkrishna Shedde  24277_sa@nttdataser.com
#
#   country  manager_portalid  grade employee_type  Training Goal  hireddate  \
# 0     IND           24687.0     12      Employee           18.0 1997-11-24
# 1     IND           24731.0     13      Employee           18.0 1998-03-02
# 2     IND           24716.0     13      Employee           18.0 1998-05-04
# 3     IND           24747.0     13      Employee           18.0 1998-05-18
# 4     IND           24749.0     13      Employee           18.0 1998-07-06
#
# ...

# %%
df.to_excel(file, sheet_name="Data", index=False)
